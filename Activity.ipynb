# %% [markdown]
# <a href="https://colab.research.google.com/github/Preciousdisono/BSIS-2A-PRECIOUS-KEZIAH-DISONO/blob/main/Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Preciousdisono/BSIS-2A-PRECIOUS-KEZIAH-DISONO/refs/heads/main/student%20performace.csv')

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0            7.0             99.0                        NaN          NaN
# 1            4.0             82.0                         No          4.0
# 2            8.0             51.0                        Yes          7.0
# 3            5.0             52.0                        NaN          5.0
# 4            7.0             75.0                         No          NaN
#
#    Sample Question Papers Practiced  Performance Index  Unnamed: 6
# 0                               1.0               91.0         NaN
# 1                               2.0               65.0         NaN
# 2                               2.0               45.0         NaN
# 3                               2.0               36.0         NaN
# 4                               5.0               66.0         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     49 non-null     float64
#  1   Previous Scores                   49 non-null     float64
#  2   Extracurricular Activities        38 non-null     object
#  3   Sleep Hours                       45 non-null     float64
#  4   Sample Question Papers Practiced  49 non-null     float64
#  5   Performance Index                 49 non-null     float64
#  6   Unnamed: 6                        0 non-null      float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
(df.isnull().sum())
# Out:
# Hours Studied                        1
# Previous Scores                      1
# Extracurricular Activities          12
# Sleep Hours                          5
# Sample Question Papers Practiced     1
# Performance Index                    1
# Unnamed: 6                          50
# dtype: int64

# %%
lf = df.drop(columns=['Sleep Hours'])

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0            7.0             99.0                        NaN          NaN
# 1            4.0             82.0                         No          4.0
# 2            8.0             51.0                        Yes          7.0
# 3            5.0             52.0                        NaN          5.0
# 4            7.0             75.0                         No          NaN
#
#    Sample Question Papers Practiced  Performance Index  Unnamed: 6
# 0                               1.0               91.0         NaN
# 1                               2.0               65.0         NaN
# 2                               2.0               45.0         NaN
# 3                               2.0               36.0         NaN
# 4                               5.0               66.0         NaN

# %%
df_filna = df.fillna('N/A')

# %%
df_filna.head()
# Out:
#   Hours Studied Previous Scores Extracurricular Activities Sleep Hours  \
# 0           7.0            99.0                        N/A         N/A
# 1           4.0            82.0                         No         4.0
# 2           8.0            51.0                        Yes         7.0
# 3           5.0            52.0                        N/A         5.0
# 4           7.0            75.0                         No         N/A
#
#   Sample Question Papers Practiced Performance Index Unnamed: 6
# 0                              1.0              91.0        N/A
# 1                              2.0              65.0        N/A
# 2                              2.0              45.0        N/A
# 3                              2.0              36.0        N/A
# 4                              5.0              66.0        N/A
